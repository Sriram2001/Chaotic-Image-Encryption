# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import time
import functools
import torch
import torch.backends.cudnn as cudnn
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.utils.data
import torchvision.utils as vutils
from torch.autograd import Variable
from torch.utils.data import DataLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class UnetGenerator(nn.Module):
    def __init__(self, input_nc, output_nc, num_downs, ngf=64,
                 norm_layer=nn.BatchNorm2d, use_dropout=False, output_function=nn.Sigmoid):
        super(UnetGenerator, self).__init__()
        unet_block = UnetSkipConnectionBlock(ngf * 8, ngf * 8, input_nc=None, submodule=None, norm_layer=norm_layer, innermost=True)
        for i in range(num_downs - 5):
            unet_block = UnetSkipConnectionBlock(ngf * 8, ngf * 8, input_nc=None, submodule=unet_block, norm_layer=norm_layer, use_dropout=use_dropout)
        unet_block = UnetSkipConnectionBlock(ngf * 4, ngf * 8, input_nc=None, submodule=unet_block, norm_layer=norm_layer)
        unet_block = UnetSkipConnectionBlock(ngf * 2, ngf * 4, input_nc=None, submodule=unet_block, norm_layer=norm_layer)
        unet_block = UnetSkipConnectionBlock(ngf, ngf * 2, input_nc=None, submodule=unet_block, norm_layer=norm_layer)
        unet_block = UnetSkipConnectionBlock(output_nc, ngf, input_nc=input_nc, submodule=unet_block, outermost=True, norm_layer=norm_layer)

        self.model = unet_block

    def forward(self, input):
        return self.model(input)

class UnetSkipConnectionBlock(nn.Module):
    def __init__(self, outer_nc, inner_nc, input_nc=None,submodule=None, outermost=False, innermost=False, norm_layer=nn.BatchNorm2d, use_dropout=False, output_function=nn.Sigmoid):
        super(UnetSkipConnectionBlock, self).__init__()
        self.outermost = outermost
        if type(norm_layer) == functools.partial:
            use_bias = norm_layer.func == nn.InstanceNorm2d
        else:
            use_bias = norm_layer == nn.InstanceNorm2d
        if input_nc is None:
            input_nc = outer_nc
        downconv = nn.Conv2d(input_nc, inner_nc, kernel_size=4,
                             stride=2, padding=1, bias=use_bias)
        downrelu = nn.LeakyReLU(0.2, True)
        downnorm = norm_layer(inner_nc)
        uprelu = nn.ReLU(True)
        upnorm = norm_layer(outer_nc)

        if outermost:
            upconv = nn.ConvTranspose2d(inner_nc * 2, outer_nc,
                                        kernel_size=4, stride=2,
                                        padding=1)
            down = [downconv]
            if output_function == nn.Tanh:
                up = [uprelu, upconv, nn.Tanh()]
            else:
                up = [uprelu, upconv, nn.Sigmoid()]
            model = down + [submodule] + up
        elif innermost:
            upconv = nn.ConvTranspose2d(inner_nc, outer_nc,
                                        kernel_size=4, stride=2,
                                        padding=1, bias=use_bias)
            down = [downrelu, downconv]
            up = [uprelu, upconv, upnorm]
            model = down + up
        else:
            upconv = nn.ConvTranspose2d(inner_nc * 2, outer_nc,
                                        kernel_size=4, stride=2,
                                        padding=1, bias=use_bias)
            down = [downrelu, downconv, downnorm]
            up = [uprelu, upconv, upnorm]

            if use_dropout:
                model = down + [submodule] + up + [nn.Dropout(0.5)]
            else:
                model = down + [submodule] + up

        self.model = nn.Sequential(*model)

    def forward(self, x):
        if self.outermost:
            return self.model(x)
        else:
            return torch.cat([x, self.model(x)], 1)

# %%
class RevealNet(nn.Module):
    def __init__(self):
        super(RevealNet, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(3, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(True),
            nn.Conv2d(256, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.Conv2d(128, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.Conv2d(64, 3, 3, 1, 1),
            nn.Sigmoid())

    def forward(self, input):
        output=self.main(input)
        return output

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_(0)

# %%
def print_log(log_info, log_path, console=True):
    print(log_info)

# %%
def save_result_pic(this_batch_size, originalLabelv, ContainerImg, secretLabelv, RevSecImg, epoch, i, save_path):
    originalFrames = originalLabelv.resize_(this_batch_size, 3, 256, 256)
    containerFrames = ContainerImg.resize_(this_batch_size, 3, 256, 256)
    secretFrames = secretLabelv.resize_(this_batch_size, 3,256, 256)
    revSecFrames = RevSecImg.resize_(this_batch_size, 3, 256, 256)
    showContainer = torch.cat([originalFrames, containerFrames], 0)
    showReveal = torch.cat([secretFrames, revSecFrames], 0)
    resultImg = torch.cat([showContainer, showReveal], 0)
    resultImgName = '%s/ResultImage_epoch%03d_batch%04d.png' % (save_path, epoch, i)
    vutils.save_image(resultImg, resultImgName, nrow=this_batch_size, padding=1, normalize=True)

# %%
class AverageMeter(object):
    def __init__(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
def train(train_loader, epoch, Hnet, Rnet, criterion, epochs):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    Hlosses = AverageMeter() 
    Rlosses = AverageMeter() 
    SumLosses = AverageMeter()  

    Hnet.train()
    Rnet.train()

    start_time = time.time()
    for i, batch_data in enumerate(train_loader):
        data_time.update(time.time() - start_time)

        Hnet.zero_grad()
        Rnet.zero_grad()

        all_pics, _ = batch_data 
        this_batch_size = int(all_pics.size()[0] / 2)  

       
        cover_img = all_pics[0:this_batch_size, :, :, :] 
        secret_img = all_pics[this_batch_size:this_batch_size * 2, :, :, :]

        concat_img = torch.cat([cover_img, secret_img], dim=1)

        if  torch.cuda.is_available():
            cover_img = cover_img.cuda()
            secret_img = secret_img.cuda()
            concat_img = concat_img.cuda()

        concat_imgv = Variable(concat_img)
        cover_imgv = Variable(cover_img)

        container_img = Hnet(concat_imgv) 
        errH = criterion(container_img, cover_imgv)
        Hlosses.update(errH.item(), this_batch_size)

        rev_secret_img = Rnet(container_img) 
        secret_imgv = Variable(secret_img)
        errR = criterion(rev_secret_img, secret_imgv)  
        Rlosses.update(errR.item(), this_batch_size)

        betaerrR_secret = 0.75 * errR
        err_sum = errH + betaerrR_secret
        SumLosses.update(err_sum.item(), this_batch_size)

        err_sum.backward()

        optimizerH.step()
        optimizerR.step()

        batch_time.update(time.time() - start_time)
        start_time = time.time()

        log = '[%d/%d][%d/%d]\tHnet Loss: %.4f\tRnet Loss: %.4f\tOverall loss: %.4f \t datatime: %.4f \t batchtime: %.4f' % (
            epoch + 1, epochs, i, len(train_loader),
            Hlosses.val, Rlosses.val, SumLosses.val, data_time.val, batch_time.val)

        if i % 5 == 0:
            print(log)

        if i % resultPicFrequency == 0:
            save_result_pic(this_batch_size, cover_img, container_img.data, secret_img, rev_secret_img.data, epoch, i,
                            trainpics)

    epoch_log = "----------------------------  one epoch time is %.4f  ----------------------------" % (
        batch_time.sum) + "\n"
    epoch_log = epoch_log + "Learning rates: Hnet = %.8f      Rnet = %.8f" % (
        optimizerH.param_groups[0]['lr'], optimizerR.param_groups[0]['lr']) + "\n"
    epoch_log = epoch_log + "Average Hnet Loss for the epoch=%.6f\t Average Rnet Loss for the epoch=%.6f\t Total Average loss for the epoch=%.6f" % (
        Hlosses.avg, Rlosses.avg, SumLosses.avg)
    print(epoch_log)

# %%
DATA_DIR = '/content/drive/My Drive'
traindir = os.path.join(DATA_DIR, '')
train_dataset = ImageFolder(
        traindir,
        transforms.Compose([
            transforms.Resize([256, 256]),  
            transforms.ToTensor(),
           ]))

print(len(train_dataset))
resultPicFrequency = 50
trainpics = '/content/drive/My Drive/results'
# Out:
# 49110

# %%
Hnet = UnetGenerator(input_nc=6, output_nc=3, num_downs=7, output_function=nn.Sigmoid)
Hnet = Hnet.cuda()
Hnet.apply(weights_init)

Rnet = RevealNet()
Rnet = Rnet.cuda()
Rnet.apply(weights_init)

criterion = nn.MSELoss().cuda()

# %%
optimizerH = optim.Adam(Hnet.parameters(), lr=0.001, betas=(0.5, 0.999))
optimizerR = optim.Adam(Rnet.parameters(), lr=0.001, betas=(0.5, 0.999))
num_epochs = 3
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=8)
print("------------------------- training is beginning -------------------------")
for epoch in range(num_epochs):
    print("Epoch - ", epoch + 1)
    train(train_loader, epoch, Hnet=Hnet, Rnet=Rnet, criterion=criterion, epochs=num_epochs)
    torch.save(Hnet.state_dict(), '/content/drive/My Drive/results/epoch{}.pth'.format(epoch+1))
# Out:
# ------------------------- training is beginning -------------------------
# Epoch -  1
# [1/3][0/1535]	Hnet Loss: 0.0843	Rnet Loss: 0.0894	Overall loss: 0.1513 	 datatime: 13.2054 	 batchtime: 13.6508
# [1/3][5/1535]	Hnet Loss: 0.0360	Rnet Loss: 0.0333	Overall loss: 0.0610 	 datatime: 0.0019 	 batchtime: 0.9849
# [1/3][10/1535]	Hnet Loss: 0.0185	Rnet Loss: 0.0180	Overall loss: 0.0321 	 datatime: 0.0001 	 batchtime: 0.9908
# [1/3][15/1535]	Hnet Loss: 0.0193	Rnet Loss: 0.0207	Overall loss: 0.0348 	 datatime: 0.0001 	 batchtime: 0.9869
# [1/3][20/1535]	Hnet Loss: 0.0260	Rnet Loss: 0.0258	Overall loss: 0.0453 	 datatime: 0.0001 	 batchtime: 0.9888
# [1/3][25/1535]	Hnet Loss: 0.0181	Rnet Loss: 0.0250	Overall loss: 0.0369 	 datatime: 0.0001 	 batchtime: 0.9929
# [1/3][30/1535]	Hnet Loss: 0.0135	Rnet Loss: 0.0295	Overall loss: 0.0356 	 datatime: 0.0001 	 batchtime: 0.9932
# [1/3][35/1535]	Hnet Loss: 0.0160	Rnet Loss: 0.0175	Overall loss: 0.0291 	 datatime: 0.0037 	 batchtime: 0.9979
# [1/3][40/1535]	Hnet Loss: 0.0107	Rnet Loss: 0.0200	Overall loss: 0.0256 	 datatime: 5.2204 	 batchtime: 5.6658
# [1/3][45/1535]	Hnet Loss: 0.0116	Rnet Loss: 0.0150	Overall loss: 0.0228 	 datatime: 0.0001 	 batchtime: 1.0035
# [1/3][50/1535]	Hnet Loss: 0.0080	Rnet Loss: 0.0232	Overall loss: 0.0255 	 datatime: 0.1626 	 batchtime: 0.9919
# [1/3][55/1535]	Hnet Loss: 0.0086	Rnet Loss: 0.0135	Overall loss: 0.0187 	 datatime: 0.0001 	 batchtime: 1.0021
1535]	Hnet Loss: 0.0048	Rnet Loss: 0.0098	Overall loss: 0.0122 	 datatime: 0.0001 	 batchtime: 1.0205
# [1/3][270/1535]	Hnet Loss: 0.0065	Rnet Loss: 0.0147	Overall loss: 0.0176 	 datatime: 0.0001 	 batchtime: 1.0248
# [1/3][275/1535]	Hnet Loss: 0.0058	Rnet Loss: 0.0073	Overall loss: 0.0112 	 datatime: 0.0001 	 batchtime: 1.0304
# [1/3][280/1535]	Hnet Loss: 0.0051	Rnet Loss: 0.0082	Overall loss: 0.0112 	 datatime: 4.8460 	 batchtime: 5.2762
# [1/3][285/1535]	Hnet Loss: 0.0064	Rnet Loss: 0.0071	Overall loss: 0.0117 	 datatime: 0.0001 	 batchtime: 1.0371
# [1/3][290/1535]	Hnet Loss: 0.0062	Rnet Loss: 0.0123	Overall loss: 0.0154 	 datatime: 0.0015 	 batchtime: 1.0259
# [1/3][295/1535]	Hnet Loss: 0.0080	Rnet Loss: 0.0103	Overall loss: 0.0158 	 datatime: 0.0001 	 batchtime: 1.0342
# [1/3][300/1535]	Hnet Loss: 0.0085	Rnet Loss: 0.0047	Overall loss: 0.0121 	 datatime: 0.0001 	 batchtime: 1.0329
# [1/3][305/1535]	Hnet Loss: 0.0049	Rnet Loss: 0.0044	Overall loss: 0.0082 	 datatime: 0.0001 	 batchtime: 1.0242
# [1/3][310/1535]	Hnet Loss: 0.0082	Rnet Loss: 0.0067	Overall loss: 0.0133 	 datatime: 0.0001 	 batchtime: 1.0268
# [1/3][315/1535]	Hnet Loss: 0.0081	Rnet Loss: 0.0092	Overall loss: 0.0150 	 datatime: 0.0001 	 batchtime: 1.0298
# [1/3][320/1535]	Hnet Loss: 0.0047	Rnet Loss: 0.0077	Overall loss: 0.0105 	 datatime: 2.5079 	 batchtime: 2.9456
# [1/3][325/1535]	Hnet Loss: 0.0046	Rnet Loss: 0.0095	Overall loss: 0.0118 	 datatime: 0.0001 	 batchtime: 1.0260
# [1/3][330/1535]	Hnet Loss: 0.0037	Rnet Loss: 0.0068	Overall loss: 0.0088 	 datatime: 7.4698 	 batchtime: 7.9222
# [1/3][335/1535]	Hnet Loss: 0.0060	Rnet Loss: 0.0068	Overall loss: 0.0111 	 datatime: 0.0001 	 batchtime: 1.0214
# [1/3][340/1535]	Hnet Loss: 0.0035	Rnet Loss: 0.0086	Overall loss: 0.0099 	 datatime: 0.0001 	 batchtime: 1.0219
# [1/3][345/1535]	Hnet Loss: 0.0090	Rnet Loss: 0.0080	Overall loss: 0.0151 	 datatime: 0.0001 	 batchtime: 1.0386
# [1/3][350/1535]	Hnet Loss: 0.0051	Rnet Loss: 0.0078	Overall loss: 0.0109 	 datatime: 0.0001 	 batchtime: 1.0352
# [1/3][355/1535]	Hnet Loss: 0.0054	Rnet Loss: 0.0081	Overall loss: 0.0114 	 datatime: 0.0001 	 batchtime: 1.0400
# [1/3][360/1535]	Hnet Loss: 0.0049	Rnet Loss: 0.0066	Overall loss: 0.0098 	 datatime: 1.0879 	 batchtime: 1.4565
# [1/3][365/1535]	Hnet Loss: 0.0061	Rnet Loss: 0.0055	Overall loss: 0.0102 	 datatime: 0.0001 	 batchtime: 1.0305
# [1/3][370/1535]	Hnet Loss: 0.0048	Rnet Loss: 0.
1535]	Hnet Loss: 0.0039	Rnet Loss: 0.0053	Overall loss: 0.0079 	 datatime: 0.0001 	 batchtime: 1.0389
# [1/3][915/1535]	Hnet Loss: 0.0043	Rnet Loss: 0.0076	Overall loss: 0.0099 	 datatime: 0.0020 	 batchtime: 1.0234
# [1/3][920/1535]	Hnet Loss: 0.0056	Rnet Loss: 0.0063	Overall loss: 0.0103 	 datatime: 0.0001 	 batchtime: 1.0218
# [1/3][925/1535]	Hnet Loss: 0.0048	Rnet Loss: 0.0088	Overall loss: 0.0114 	 datatime: 0.0001 	 batchtime: 1.0241
# [1/3][930/1535]	Hnet Loss: 0.0064	Rnet Loss: 0.0038	Overall loss: 0.0092 	 datatime: 0.0001 	 batchtime: 1.0250
# [1/3][935/1535]	Hnet Loss: 0.0041	Rnet Loss: 0.0035	Overall loss: 0.0067 	 datatime: 11.8637 	 batchtime: 12.3139
# [1/3][940/1535]	Hnet Loss: 0.0042	Rnet Loss: 0.0046	Overall loss: 0.0076 	 datatime: 0.0014 	 batchtime: 1.0181
# [1/3][945/1535]	Hnet Loss: 0.0041	Rnet Loss: 0.0057	Overall loss: 0.0084 	 datatime: 0.0001 	 batchtime: 1.0223
# [1/3][950/1535]	Hnet Loss: 0.0042	Rnet Loss: 0.0063	Overall loss: 0.0089 	 datatime: 0.0001 	 batchtime: 1.0205
# [1/3][955/1535]	Hnet Loss: 0.0047	Rnet Loss: 0.0073	Overall loss: 0.0102 	 datatime: 0.0001 	 batchtime: 1.0181
# [1/3][960/1535]	Hnet Loss: 0.0074	Rnet Loss: 0.0051	Overall loss: 0.0112 	 datatime: 0.0001 	 batchtime: 1.0205
# [1/3][965/1535]	Hnet Loss: 0.0035	Rnet Loss: 0.0079	Overall loss: 0.0094 	 datatime: 0.0001 	 batchtime: 1.0211
# [1/3][970/1535]	Hnet Loss: 0.0073	Rnet Loss: 0.0079	Overall loss: 0.0133 	 datatime: 0.0001 	 batchtime: 1.0259
# [1/3][975/1535]	Hnet Loss: 0.0065	Rnet Loss: 0.0051	Overall loss: 0.0103 	 datatime: 5.0506 	 batchtime: 5.5109
# [1/3][980/1535]	Hnet Loss: 0.0050	Rnet Loss: 0.0048	Overall loss: 0.0086 	 datatime: 0.0015 	 batchtime: 1.0260
# [1/3][985/1535]	Hnet Loss: 0.0039	Rnet Loss: 0.0072	Overall loss: 0.0093 	 datatime: 0.0001 	 batchtime: 1.0221
# [1/3][990/1535]	Hnet Loss: 0.0043	Rnet Loss: 0.0057	Overall loss: 0.0086 	 datatime: 0.0001 	 batchtime: 1.0304
# [1/3][995/1535]	Hnet Loss: 0.0045	Rnet Loss: 0.0049	Overall loss: 0.0082 	 datatime: 0.0002 	 batchtime: 1.0202
# [1/3][1000/1535]	Hnet Loss: 0.0047	Rnet Loss: 0.0084	Overall loss: 0.0110 	 datatime: 0.0001 	 batchtime: 1.0174
# [1/3][1005/1535]	Hnet Loss: 0.0033	Rnet Loss: 0.0058	Overall loss: 0.0076 	 datatime: 0.0001 	 batchtime: 1.0288
# [1/3][1010/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0100	Overall loss: 0.0106 	 datatime: 0.0001 	 batchtime: 1.0278
# [1/3][1015/1535]	Hnet Loss: 0.0038	Rnet Loss: 0.0069	Overall loss: 0.0090 	 datatime: 6.4339 	 batchtime: 6.8708
# [1/3][1020/1535]	Hnet Loss: 0.0051	Rnet Loss: 0.0055	Overall loss: 0.0092 	 datatime: 0.0015 	 batchtime: 1.0295
# [1/3][1025/1535]	Hnet Loss: 0.0046	Rnet Loss: 0.0161	Overall loss: 0.0167 	 datatime: 0.0001 	 batchtime: 1.0293
# [1/3][1030/1535]	Hnet Loss: 0.0039	Rnet Loss: 0.
1535]	Hnet Loss: 0.0037	Rnet Loss: 0.0051	Overall loss: 0.0075 	 datatime: 0.0001 	 batchtime: 1.0234
# [1/3][1460/1535]	Hnet Loss: 0.0045	Rnet Loss: 0.0033	Overall loss: 0.0070 	 datatime: 7.4492 	 batchtime: 7.8964
# [1/3][1465/1535]	Hnet Loss: 0.0032	Rnet Loss: 0.0071	Overall loss: 0.0085 	 datatime: 0.0001 	 batchtime: 1.0363
# [1/3][1470/1535]	Hnet Loss: 0.0049	Rnet Loss: 0.0083	Overall loss: 0.0112 	 datatime: 0.0001 	 batchtime: 1.0258
# [1/3][1475/1535]	Hnet Loss: 0.0048	Rnet Loss: 0.0098	Overall loss: 0.0121 	 datatime: 0.0001 	 batchtime: 1.0243
# [1/3][1480/1535]	Hnet Loss: 0.0041	Rnet Loss: 0.0041	Overall loss: 0.0071 	 datatime: 0.0035 	 batchtime: 1.0172
# [1/3][1485/1535]	Hnet Loss: 0.0042	Rnet Loss: 0.0046	Overall loss: 0.0077 	 datatime: 0.0001 	 batchtime: 1.0278
# [1/3][1490/1535]	Hnet Loss: 0.0028	Rnet Loss: 0.0043	Overall loss: 0.0061 	 datatime: 0.0001 	 batchtime: 1.0283
# [1/3][1495/1535]	Hnet Loss: 0.0032	Rnet Loss: 0.0088	Overall loss: 0.0098 	 datatime: 0.0001 	 batchtime: 1.0175
# [1/3][1500/1535]	Hnet Loss: 0.0035	Rnet Loss: 0.0048	Overall loss: 0.0071 	 datatime: 6.1260 	 batchtime: 6.5674
# [1/3][1505/1535]	Hnet Loss: 0.0039	Rnet Loss: 0.0060	Overall loss: 0.0084 	 datatime: 0.0001 	 batchtime: 1.0271
# [1/3][1510/1535]	Hnet Loss: 0.0026	Rnet Loss: 0.0045	Overall loss: 0.0060 	 datatime: 0.0001 	 batchtime: 1.0376
# [1/3][1515/1535]	Hnet Loss: 0.0049	Rnet Loss: 0.0070	Overall loss: 0.0101 	 datatime: 0.0001 	 batchtime: 1.0340
# [1/3][1520/1535]	Hnet Loss: 0.0035	Rnet Loss: 0.0039	Overall loss: 0.0064 	 datatime: 1.5852 	 batchtime: 1.9525
# [1/3][1525/1535]	Hnet Loss: 0.0027	Rnet Loss: 0.0051	Overall loss: 0.0065 	 datatime: 0.0023 	 batchtime: 1.0302
# [1/3][1530/1535]	Hnet Loss: 0.0026	Rnet Loss: 0.0078	Overall loss: 0.0084 	 datatime: 2.9023 	 batchtime: 3.3366
# ----------------------------  one epoch time is 2776.6451  ----------------------------
# Learning rates: Hnet = 0.00100000      Rnet = 0.00100000
# Average Hnet Loss for the epoch=0.005529	 Average Rnet Loss for the epoch=0.008327	 Total Average loss for the epoch=0.011774
# Epoch -  2
# [2/3][0/1535]	Hnet Loss: 0.0036	Rnet Loss: 0.0027	Overall loss: 0.0056 	 datatime: 2.1993 	 batchtime: 2.7886
# [2/3][5/1535]	Hnet Loss: 0.0030	Rnet Loss: 0.0045	Overall loss: 0.0063 	 datatime: 0.0050 	 batchtime: 1.0213
# [2/3][10/1535]	Hnet Loss: 0.0036	Rnet Loss: 0.0057	Overall loss: 0.0078 	 datatime: 0.0035 	 batchtime: 1.0281
# [2/3][15/1535]	Hnet Loss: 0.0046	Rnet Loss: 0.0063	Overall loss: 0.0094 	 datatime: 0.0001 	 batchtime: 1.0364
# [2/3][20/1535]	Hnet Loss: 0.0039	Rnet Loss: 0.0033	Overall loss: 0.0064 	 datatime: 0.0015 	 batchtime: 1.0357
# [2/3][25/1535]	Hnet Loss: 0.0034	Rnet Loss: 0.0039	Overall loss: 0.0064 	 datatime: 0.0014 	 batchtime: 1.0375
# [2/3][30/1535]	Hnet Loss: 0.0022	Rnet Loss: 0.0035	Overall loss: 0.0048 	 datatime: 0.0022 	 batchtime: 1.0417
# [2/3][35/1535]	Hnet Loss: 0.0026	Rnet Loss: 0.0035	Overall loss: 0.0052 	 datatime: 0.0020 	 batchtime: 1.0397
# [2/3][40/1535]	Hnet Loss: 0.0029	Rnet Loss: 0.0048	Overall loss: 0.0065 	 datatime: 0.0015 	 batchtime: 1.0388
# [2/3][45/1535]	Hnet Loss: 0.0041	Rnet Loss: 0.0050	Overall loss: 0.0078 	 datatime: 0.0015 	 batchtime: 1.0397
# [2/3][50/1535]	Hnet Loss: 0.0049	Rnet Loss: 0.0152	Overall loss: 0.0163 	 datatime: 0.0015 	 batchtime: 1.0397
# [2/3][55/1535]	Hnet Loss: 0.0033	Rnet Loss: 0.0062	Overall loss: 0.0080 	 datatime: 0.0015 	 batchtime: 1.0386
# [2/3][60/1535]	Hnet Loss: 0.0029	Rnet Loss: 0.0111	Overall loss: 0.0112 	 datatime: 0.0015 	 batchtime: 1.0392
# [2/3][65/1535]	Hnet Loss: 0.0052	Rnet Loss: 0.0057	Overall loss: 0.0095 	 datatime: 0.0015 	 batchtime: 1.0458
# [2/3][70/1535]	Hnet Loss: 0.0048	Rnet Loss: 0.0119	Overall loss: 0.0138 	 datatime: 0.0015 	 batchtime: 1.0462
# [2/3][75/1535]	Hnet Loss: 0.0034	Rnet Loss: 0.0038	Overall loss: 0.0063 	 datatime: 0.0016 	 batchtime: 1.0472
# [2/3][80/1535]	Hnet Loss: 0.0042	Rnet Loss: 0.0060	Overall loss: 0.0087 	 datatime: 0.0015 	 batchtime: 1.0524
# [2/3][85/1535]	Hnet Loss: 0.0020	Rnet Loss: 0.0030	Overall loss: 0.0043 	 datatime: 0.0015 	 batchtime: 1.0576
# [2/3][90/1535]	Hnet Loss: 0.0028	Rnet Loss: 0.0046	Overall loss: 0.0063 	 datatime: 0.0016 	 batchtime: 1.0562
# [2/3][95/1535]	Hnet Loss: 0.0042	Rnet Loss: 0.0103	Overall loss: 0.0120 	 datatime: 0.0015 	 batchtime: 1.0550
# [2/3][100/1535]	Hnet Loss: 0.0039	Rnet Loss: 0.0029	Overall loss: 0.0061 	 datatime: 0.0015 	 batchtime: 1.0547
# [2/3][105/1535]	Hnet Loss: 0.0039	Rnet Loss: 0.0033	Overall loss: 0.0064 	 datatime: 0.0015 	 batchtime: 1.0522
# [2/3][110/1535]	Hnet Loss: 0.0037	Rnet Loss: 0.0044	Overall loss: 0.0069 	 datatime: 0.0015 	 batchtime: 1.0529
# [2/3][115/1535]	Hnet Loss: 0.0030	Rnet Loss: 0.0040	Overall loss: 0.0060 	 datatime: 0.0016 	 batchtime: 1.0536
# [2/3][120/1535]	Hnet Loss: 0.0027	Rnet Loss: 0.0053	Overall loss: 0.0067 	 datatime: 0.0016 	 batchtime: 1.0557
# [2/3][125/1535]	Hnet Loss: 0.0042	Rnet Loss: 0.0055	Overall loss: 0.0083 	 datatime: 0.0015 	 batchtime: 1.0539
# [2/3][130/1535]	Hnet Loss: 0.0029	Rnet Loss: 0.0086	Overall loss: 0.0094 	 datatime: 0.0017 	 batchtime: 1.0552
# [2/3][135/1535]	Hnet Loss: 0.0026	Rnet Loss: 0.0085	Overall loss: 0.0090 	 datatime: 0.0016 	 batchtime: 1.0556
# [2/3][140/1535]	Hnet Loss: 0.0030	Rnet Loss: 0.0046	Overall loss: 0.0064 	 datatime: 0.0015 	 batchtime: 1.0538
# [2/3][145/1535]	Hnet Loss: 0.0039	Rnet Loss: 0.0046	Overall loss: 0.0073 	 datatime: 0.0016 	 batchtime: 1.0542
# [2/3][150/1535]	Hnet Loss: 0.0044	Rnet Loss: 0.0053	Overall loss: 0.0084 	 datatime: 0.0018 	 batchtime: 1.0587
# [2/3][155/1535]	Hnet Loss: 0.0041	Rnet Loss: 0.0063	Overall loss: 0.0089 	 datatime: 0.0019 	 batchtime: 1.0517
# [2/3][160/1535]	Hnet Loss: 0.0024	Rnet Loss: 0.0059	Overall loss: 0.0068 	 datatime: 0.0015 	 batchtime: 1.0541
# [2/3][165/1535]	Hnet Loss: 0.0032	Rnet Loss: 0.0047	Overall loss: 0.0067 	 datatime: 0.0016 	 batchtime: 1.0575
# [2/3][170/1535]	Hnet Loss: 0.0023	Rnet Loss: 0.0048	Overall loss: 0.0060 	 datatime: 0.0014 	 batchtime: 1.0553
# [2/3][175/1535]	Hnet Loss: 0.0043	Rnet Loss: 0.0032	Overall loss: 0.0067 	 datatime: 0.0014 	 batchtime: 1.0603
# [2/3][180/1535]	Hnet Loss: 0.0032	Rnet Loss: 0.0049	Overall loss: 0.0068 	 datatime: 0.0014 	 batchtime: 1.0572
# [2/3][185/1535]	Hnet Loss: 0.0038	Rnet Loss: 0.0062	Overall loss: 0.0085 	 datatime: 0.0016 	 batchtime: 1.0591
# [2/3][190/1535]	Hnet Loss: 0.0032	Rnet Loss: 0.0044	Overall loss: 0.0065 	 datatime: 0.0015 	 batchtime: 1.0591
# [2/3][195/1535]	Hnet Loss: 0.0028	Rnet Loss: 0.0049	Overall loss: 0.0065 	 datatime: 0.0015 	 batchtime: 1.0548
# [2/3][200/1535]	Hnet Loss: 0.0035	Rnet Loss: 0.0062	Overall loss: 0.0081 	 datatime: 0.0015 	 batchtime: 1.0551
# [2/3][205/1535]	Hnet Loss: 0.0029	Rnet Loss: 0.0055	Overall loss: 0.0070 	 datatime: 0.0015 	 batchtime: 1.0529
# [2/3][210/1535]	Hnet Loss: 0.0033	Rnet Loss: 0.
1535]	Hnet Loss: 0.0027	Rnet Loss: 0.0072	Overall loss: 0.0081 	 datatime: 0.0015 	 batchtime: 1.0646
# [2/3][360/1535]	Hnet Loss: 0.0033	Rnet Loss: 0.0045	Overall loss: 0.0067 	 datatime: 0.0014 	 batchtime: 1.0537
# [2/3][365/1535]	Hnet Loss: 0.0043	Rnet Loss: 0.0088	Overall loss: 0.0109 	 datatime: 0.0014 	 batchtime: 1.0537
# [2/3][370/1535]	Hnet Loss: 0.0032	Rnet Loss: 0.0046	Overall loss: 0.0067 	 datatime: 0.0015 	 batchtime: 1.0546
# [2/3][375/1535]	Hnet Loss: 0.0030	Rnet Loss: 0.0035	Overall loss: 0.0056 	 datatime: 0.0015 	 batchtime: 1.0562
# [2/3][380/1535]	Hnet Loss: 0.0048	Rnet Loss: 0.0046	Overall loss: 0.0082 	 datatime: 0.0015 	 batchtime: 1.0524
# [2/3][385/1535]	Hnet Loss: 0.0034	Rnet Loss: 0.0107	Overall loss: 0.0114 	 datatime: 0.0015 	 batchtime: 1.0563
# [2/3][390/1535]	Hnet Loss: 0.0049	Rnet Loss: 0.0028	Overall loss: 0.0070 	 datatime: 0.0014 	 batchtime: 1.0543
# [2/3][395/1535]	Hnet Loss: 0.0024	Rnet Loss: 0.0038	Overall loss: 0.0052 	 datatime: 0.0014 	 batchtime: 1.0577
# [2/3][400/1535]	Hnet Loss: 0.0054	Rnet Loss: 0.0042	Overall loss: 0.0085 	 datatime: 0.0014 	 batchtime: 1.0569
# [2/3][405/1535]	Hnet Loss: 0.0035	Rnet Loss: 0.0064	Overall loss: 0.0083 	 datatime: 0.0014 	 batchtime: 1.0543
# [2/3][410/1535]	Hnet Loss: 0.0051	Rnet Loss: 0.0039	Overall loss: 0.0080 	 datatime: 0.0014 	 batchtime: 1.0566
# [2/3][415/1535]	Hnet Loss: 0.0025	Rnet Loss: 0.0050	Overall loss: 0.0062 	 datatime: 0.0014 	 batchtime: 1.0548
# [2/3][420/1535]	Hnet Loss: 0.0041	Rnet Loss: 0.0063	Overall loss: 0.0088 	 datatime: 0.0014 	 batchtime: 1.0572
# [2/3][425/1535]	Hnet Loss: 0.0040	Rnet Loss: 0.0057	Overall loss: 0.0083 	 datatime: 0.0014 	 batchtime: 1.0577
# [2/3][430/1535]	Hnet Loss: 0.0026	Rnet Loss: 0.0040	Overall loss: 0.0056 	 datatime: 0.0015 	 batchtime: 1.0590
# [2/3][435/1535]	Hnet Loss: 0.0037	Rnet Loss: 0.0037	Overall loss: 0.0065 	 datatime: 0.0031 	 batchtime: 1.0551
# [2/3][440/1535]	Hnet Loss: 0.0059	Rnet Loss: 0.0036	Overall loss: 0.0085 	 datatime: 0.0014 	 batchtime: 1.0560
# [2/3][445/1535]	Hnet Loss: 0.0030	Rnet Loss: 0.0039	Overall loss: 0.0059 	 datatime: 0.0015 	 batchtime: 1.0612
# [2/3][450/1535]	Hnet Loss: 0.0020	Rnet Loss: 0.0065	Overall loss: 0.0069 	 datatime: 0.0014 	 batchtime: 1.0572
# [2/3][455/1535]	Hnet Loss: 0.0044	Rnet Loss: 0.0068	Overall loss: 0.0095 	 datatime: 0.0014 	 batchtime: 1.0529
# [2/3][460/1535]	Hnet Loss: 0.0024	Rnet Loss: 0.0038	Overall loss: 0.0052 	 datatime: 0.0014 	 batchtime: 1.0561
# [2/3][465/1535]	Hnet Loss: 0.0034	Rnet Loss: 0.0042	Overall loss: 0.0065 	 datatime: 0.0016 	 batchtime: 1.0562
# [2/3][470/1535]	Hnet Loss: 0.0034	Rnet Loss: 0.0062	Overall loss: 0.0081 	 datatime: 0.0014 	 batchtime: 1.0569
# [2/3][475/1535]	Hnet Loss: 0.0028	Rnet Loss: 0.0052	Overall loss: 0.0067 	 datatime: 0.0014 	 batchtime: 1.0575
# [2/3][480/1535]	Hnet Loss: 0.0023	Rnet Loss: 0.0025	Overall loss: 0.0042 	 datatime: 0.0015 	 batchtime: 1.0554
# [2/3][485/1535]	Hnet Loss: 0.0026	Rnet Loss: 0.0043	Overall loss: 0.0058 	 datatime: 0.0014 	 batchtime: 1.0587
# [2/3][490/1535]	Hnet Loss: 0.0036	Rnet Loss: 0.0039	Overall loss: 0.0065 	 datatime: 0.0014 	 batchtime: 1.0588
# [2/3][495/1535]	Hnet Loss: 0.0025	Rnet Loss: 0.0033	Overall loss: 0.0049 	 datatime: 0.0014 	 batchtime: 1.0600
# [2/3][500/1535]	Hnet Loss: 0.0044	Rnet Loss: 0.0035	Overall loss: 0.0070 	 datatime: 0.0014 	 batchtime: 1.0538
# [2/3][505/1535]	Hnet Loss: 0.0032	Rnet Loss: 0.0047	Overall loss: 0.0068 	 datatime: 0.0014 	 batchtime: 1.0539
# [2/3][510/1535]	Hnet Loss: 0.0054	Rnet Loss: 0.0045	Overall loss: 0.0088 	 datatime: 0.0014 	 batchtime: 1.0519
# [2/3][515/1535]	Hnet Loss: 0.0022	Rnet Loss: 0.0036	Overall loss: 0.0049 	 datatime: 0.0014 	 batchtime: 1.0542
# [2/3][520/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0032	Overall loss: 0.0054 	 datatime: 0.0014 	 batchtime: 1.0555
# [2/3][525/1535]	Hnet Loss: 0.0033	Rnet Loss: 0.0057	Overall loss: 0.0076 	 datatime: 0.0014 	 batchtime: 1.0559
# [2/3][530/1535]	Hnet Loss: 0.0046	Rnet Loss: 0.0070	Overall loss: 0.0099 	 datatime: 0.0014 	 batchtime: 1.0555
# [2/3][535/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0043	Overall loss: 0.0063 	 datatime: 0.0014 	 batchtime: 1.0573
# [2/3][540/1535]	Hnet Loss: 0.0035	Rnet Loss: 0.0085	Overall loss: 0.0099 	 datatime: 0.0013 	 batchtime: 1.0574
# [2/3][545/1535]	Hnet Loss: 0.0039	Rnet Loss: 0.0034	Overall loss: 0.0064 	 datatime: 0.0015 	 batchtime: 1.0582
# [2/3][550/1535]	Hnet Loss: 0.0034	Rnet Loss: 0.0030	Overall loss: 0.0057 	 datatime: 0.0014 	 batchtime: 1.0611
# [2/3][555/1535]	Hnet Loss: 0.0021	Rnet Loss: 0.0064	Overall loss: 0.0069 	 datatime: 0.0016 	 batchtime: 1.0525
# [2/3][560/1535]	Hnet Loss: 0.0039	Rnet Loss: 0.0040	Overall loss: 0.0069 	 datatime: 0.0015 	 batchtime: 1.0548
# [2/3][565/1535]	Hnet Loss: 0.0025	Rnet Loss: 0.0052	Overall loss: 0.0064 	 datatime: 0.0013 	 batchtime: 1.0537
# [2/3][570/1535]	Hnet Loss: 0.0027	Rnet Loss: 0.0049	Overall loss: 0.0063 	 datatime: 0.0014 	 batchtime: 1.0574
# [2/3][575/1535]	Hnet Loss: 0.0034	Rnet Loss: 0.0068	Overall loss: 0.0085 	 datatime: 0.0014 	 batchtime: 1.0543
# [2/3][580/1535]	Hnet Loss: 0.0024	Rnet Loss: 0.0102	Overall loss: 0.0101 	 datatime: 0.0014 	 batchtime: 1.0536
# ...
# [3/3][840/1535]	Hnet Loss: 0.0024	Rnet Loss: 0.0025	Overall loss: 0.0042 	 datatime: 0.0013 	 batchtime: 1.0542
# [3/3][845/1535]	Hnet Loss: 0.0030	Rnet Loss: 0.0035	Overall loss: 0.0056 	 datatime: 0.0013 	 batchtime: 1.0568
# [3/3][850/1535]	Hnet Loss: 0.0027	Rnet Loss: 0.0027	Overall loss: 0.0047 	 datatime: 0.0017 	 batchtime: 1.0536
# [3/3][855/1535]	Hnet Loss: 0.0028	Rnet Loss: 0.0071	Overall loss: 0.0082 	 datatime: 0.0015 	 batchtime: 1.0535
# [3/3][860/1535]	Hnet Loss: 0.0024	Rnet Loss: 0.0029	Overall loss: 0.0045 	 datatime: 0.0014 	 batchtime: 1.0526
# [3/3][865/1535]	Hnet Loss: 0.0021	Rnet Loss: 0.0037	Overall loss: 0.0049 	 datatime: 0.0013 	 batchtime: 1.0519
# [3/3][870/1535]	Hnet Loss: 0.0030	Rnet Loss: 0.0028	Overall loss: 0.0051 	 datatime: 0.0013 	 batchtime: 1.0525
# [3/3][875/1535]	Hnet Loss: 0.0044	Rnet Loss: 0.0031	Overall loss: 0.0067 	 datatime: 0.0014 	 batchtime: 1.0575
# [3/3][880/1535]	Hnet Loss: 0.0022	Rnet Loss: 0.0050	Overall loss: 0.0059 	 datatime: 0.0014 	 batchtime: 1.0529
# [3/3][885/1535]	Hnet Loss: 0.0028	Rnet Loss: 0.0064	Overall loss: 0.0076 	 datatime: 0.0014 	 batchtime: 1.0535
# [3/3][890/1535]	Hnet Loss: 0.0024	Rnet Loss: 0.0032	Overall loss: 0.0049 	 datatime: 0.0013 	 batchtime: 1.0530
# [3/3][895/1535]	Hnet Loss: 0.0039	Rnet Loss: 0.0039	Overall loss: 0.0068 	 datatime: 0.0014 	 batchtime: 1.0535
# [3/3][900/1535]	Hnet Loss: 0.0024	Rnet Loss: 0.0034	Overall loss: 0.0050 	 datatime: 0.0015 	 batchtime: 1.0532
# [3/3][905/1535]	Hnet Loss: 0.0017	Rnet Loss: 0.0030	Overall loss: 0.0040 	 datatime: 0.0014 	 batchtime: 1.0568
# [3/3][910/1535]	Hnet Loss: 0.0036	Rnet Loss: 0.0117	Overall loss: 0.0123 	 datatime: 0.0014 	 batchtime: 1.0554
# [3/3][915/1535]	Hnet Loss: 0.0026	Rnet Loss: 0.0045	Overall loss: 0.0060 	 datatime: 0.0017 	 batchtime: 1.0537
# [3/3][920/1535]	Hnet Loss: 0.0024	Rnet Loss: 0.0044	Overall loss: 0.0057 	 datatime: 0.0013 	 batchtime: 1.0522
# [3/3][925/1535]	Hnet Loss: 0.0032	Rnet Loss: 0.0038	Overall loss: 0.0061 	 datatime: 0.0013 	 batchtime: 1.0534
# [3/3][930/1535]	Hnet Loss: 0.0036	Rnet Loss: 0.0036	Overall loss: 0.0063 	 datatime: 0.0014 	 batchtime: 1.0556
# [3/3][935/1535]	Hnet Loss: 0.0026	Rnet Loss: 0.0063	Overall loss: 0.0074 	 datatime: 0.0014 	 batchtime: 1.0603
# [3/3][940/1535]	Hnet Loss: 0.0033	Rnet Loss: 0.0038	Overall loss: 0.0061 	 datatime: 0.0014 	 batchtime: 1.0487
# [3/3][945/1535]	Hnet Loss: 0.0027	Rnet Loss: 0.0032	Overall loss: 0.0051 	 datatime: 0.0014 	 batchtime: 1.0537
# [3/3][950/1535]	Hnet Loss: 0.0024	Rnet Loss: 0.0033	Overall loss: 0.0048 	 datatime: 0.0014 	 batchtime: 1.0518
# [3/3][955/1535]	Hnet Loss: 0.0028	Rnet Loss: 0.0032	Overall loss: 0.0052 	 datatime: 0.0013 	 batchtime: 1.0530
# [3/3][960/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0042	Overall loss: 0.0062 	 datatime: 0.0014 	 batchtime: 1.0519
# [3/3][965/1535]	Hnet Loss: 0.0032	Rnet Loss: 0.0041	Overall loss: 0.0063 	 datatime: 0.0014 	 batchtime: 1.0533
# [3/3][970/1535]	Hnet Loss: 0.0025	Rnet Loss: 0.0041	Overall loss: 0.0056 	 datatime: 0.0013 	 batchtime: 1.0529
# [3/3][975/1535]	Hnet Loss: 0.0018	Rnet Loss: 0.0036	Overall loss: 0.0045 	 datatime: 0.0014 	 batchtime: 1.0522
# [3/3][980/1535]	Hnet Loss: 0.0020	Rnet Loss: 0.0040	Overall loss: 0.0050 	 datatime: 0.0014 	 batchtime: 1.0548
# [3/3][985/1535]	Hnet Loss: 0.0038	Rnet Loss: 0.0037	Overall loss: 0.0066 	 datatime: 0.0014 	 batchtime: 1.0524
# [3/3][990/1535]	Hnet Loss: 0.0021	Rnet Loss: 0.0044	Overall loss: 0.0054 	 datatime: 0.0014 	 batchtime: 1.0532
# [3/3][995/1535]	Hnet Loss: 0.0044	Rnet Loss: 0.0041	Overall loss: 0.0075 	 datatime: 0.0013 	 batchtime: 1.0545
# [3/3][1000/1535]	Hnet Loss: 0.0016	Rnet Loss: 0.0067	Overall loss: 0.0067 	 datatime: 0.0014 	 batchtime: 1.0536
# [3/3][1005/1535]	Hnet Loss: 0.0023	Rnet Loss: 0.0037	Overall loss: 0.0051 	 datatime: 0.0016 	 batchtime: 1.0537
# [3/3][1010/1535]	Hnet Loss: 0.0020	Rnet Loss: 0.0049	Overall loss: 0.0056 	 datatime: 0.0017 	 batchtime: 1.0529
# [3/3][1015/1535]	Hnet Loss: 0.0021	Rnet Loss: 0.0050	Overall loss: 0.0058 	 datatime: 0.0014 	 batchtime: 1.0536
# [3/3][1020/1535]	Hnet Loss: 0.0041	Rnet Loss: 0.0036	Overall loss: 0.0068 	 datatime: 0.0013 	 batchtime: 1.0514
# [3/3][1025/1535]	Hnet Loss: 0.0025	Rnet Loss: 0.0028	Overall loss: 0.0046 	 datatime: 0.0014 	 batchtime: 1.0533
# [3/3][1030/1535]	Hnet Loss: 0.0022	Rnet Loss: 0.0036	Overall loss: 0.0049 	 datatime: 0.0014 	 batchtime: 1.0528
# [3/3][1035/1535]	Hnet Loss: 0.0036	Rnet Loss: 0.0044	Overall loss: 0.0069 	 datatime: 0.0014 	 batchtime: 1.0538
# [3/3][1040/1535]	Hnet Loss: 0.0021	Rnet Loss: 0.0023	Overall loss: 0.0038 	 datatime: 0.0014 	 batchtime: 1.0555
# [3/3][1045/1535]	Hnet Loss: 0.0019	Rnet Loss: 0.0037	Overall loss: 0.0047 	 datatime: 0.0014 	 batchtime: 1.0542
# [3/3][1050/1535]	Hnet Loss: 0.0062	Rnet Loss: 0.0029	Overall loss: 0.0084 	 datatime: 0.0017 	 batchtime: 1.0568
# [3/3][1055/1535]	Hnet Loss: 0.0020	Rnet Loss: 0.0021	Overall loss: 0.0036 	 datatime: 0.0017 	 batchtime: 1.0558
# [3/3][1060/1535]	Hnet Loss: 0.0028	Rnet Loss: 0.0028	Overall loss: 0.0049 	 datatime: 0.0017 	 batchtime: 1.0539
# [3/3][1065/1535]	Hnet Loss: 0.0018	Rnet Loss: 0.0068	Overall loss: 0.0069 	 datatime: 0.0014 	 batchtime: 1.0531
# [3/3][1070/1535]	Hnet Loss: 0.0044	Rnet Loss: 0.0123	Overall loss: 0.0136 	 datatime: 0.0014 	 batchtime: 1.0545
# [3/3][1075/1535]	Hnet Loss: 0.0026	Rnet Loss: 0.0033	Overall loss: 0.0051 	 datatime: 0.0013 	 batchtime: 1.0550
# [3/3][1080/1535]	Hnet Loss: 0.0025	Rnet Loss: 0.0028	Overall loss: 0.0046 	 datatime: 0.0013 	 batchtime: 1.0559
# [3/3][1085/1535]	Hnet Loss: 0.0016	Rnet Loss: 0.0041	Overall loss: 0.0046 	 datatime: 0.0014 	 batchtime: 1.0430
# [3/3][1090/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0063	Overall loss: 0.0078 	 datatime: 0.0014 	 batchtime: 1.0542
# [3/3][1095/1535]	Hnet Loss: 0.0056	Rnet Loss: 0.0048	Overall loss: 0.0093 	 datatime: 0.0013 	 batchtime: 1.0601
# [3/3][1100/1535]	Hnet Loss: 0.0032	Rnet Loss: 0.0033	Overall loss: 0.0057 	 datatime: 0.0015 	 batchtime: 1.0566
# [3/3][1105/1535]	Hnet Loss: 0.0026	Rnet Loss: 0.0032	Overall loss: 0.0051 	 datatime: 0.0013 	 batchtime: 1.0574
# [3/3][1110/1535]	Hnet Loss: 0.0037	Rnet Loss: 0.0055	Overall loss: 0.0078 	 datatime: 0.0017 	 batchtime: 1.0545
# [3/3][1115/1535]	Hnet Loss: 0.0034	Rnet Loss: 0.0040	Overall loss: 0.0064 	 datatime: 0.0013 	 batchtime: 1.0530
# [3/3][1120/1535]	Hnet Loss: 0.0022	Rnet Loss: 0.0057	Overall loss: 0.0064 	 datatime: 0.0013 	 batchtime: 1.0535
# [3/3][1125/1535]	Hnet Loss: 0.0046	Rnet Loss: 0.0059	Overall loss: 0.0090 	 datatime: 0.0014 	 batchtime: 1.0560
# [3/3][1130/1535]	Hnet Loss: 0.0034	Rnet Loss: 0.0020	Overall loss: 0.0049 	 datatime: 0.0016 	 batchtime: 1.0548
# [3/3][1135/1535]	Hnet Loss: 0.0030	Rnet Loss: 0.0030	Overall loss: 0.0052 	 datatime: 0.0014 	 batchtime: 1.0580
# [3/3][1140/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0032	Overall loss: 0.0055 	 datatime: 0.0015 	 batchtime: 1.0544
# [3/3][1145/1535]	Hnet Loss: 0.0022	Rnet Loss: 0.0023	Overall loss: 0.0039 	 datatime: 0.0013 	 batchtime: 1.0561
# [3/3][1150/1535]	Hnet Loss: 0.0044	Rnet Loss: 0.0027	Overall loss: 0.0064 	 datatime: 0.0016 	 batchtime: 1.0554
# [3/3][1155/1535]	Hnet Loss: 0.0029	Rnet Loss: 0.0053	Overall loss: 0.0069 	 datatime: 0.0014 	 batchtime: 1.0534
# [3/3][1160/1535]	Hnet Loss: 0.0021	Rnet Loss: 0.0024	Overall loss: 0.0039 	 datatime: 0.0014 	 batchtime: 1.0535
# [3/3][1165/1535]	Hnet Loss: 0.0043	Rnet Loss: 0.0048	Overall loss: 0.0079 	 datatime: 0.0015 	 batchtime: 1.0523
# [3/3][1170/1535]	Hnet Loss: 0.0024	Rnet Loss: 0.0035	Overall loss: 0.0050 	 datatime: 0.0014 	 batchtime: 1.0535
# [3/3][1175/1535]	Hnet Loss: 0.0026	Rnet Loss: 0.0023	Overall loss: 0.0043 	 datatime: 0.0015 	 batchtime: 1.0587
# [3/3][1180/1535]	Hnet Loss: 0.0039	Rnet Loss: 0.0021	Overall loss: 0.0054 	 datatime: 0.0014 	 batchtime: 1.0540
# [3/3][1185/1535]	Hnet Loss: 0.0032	Rnet Loss: 0.0038	Overall loss: 0.0061 	 datatime: 0.0016 	 batchtime: 1.0573
# [3/3][1190/1535]	Hnet Loss: 0.0022	Rnet Loss: 0.0032	Overall loss: 0.0046 	 datatime: 0.0014 	 batchtime: 1.0545
# [3/3][1195/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0017	Overall loss: 0.0044 	 datatime: 0.0014 	 batchtime: 1.0549
# [3/3][1200/1535]	Hnet Loss: 0.0029	Rnet Loss: 0.0040	Overall loss: 0.0059 	 datatime: 0.0014 	 batchtime: 1.0536
# [3/3][1205/1535]	Hnet Loss: 0.0047	Rnet Loss: 0.0035	Overall loss: 0.0073 	 datatime: 0.0014 	 batchtime: 1.0550
# [3/3][1210/1535]	Hnet Loss: 0.0036	Rnet Loss: 0.0040	Overall loss: 0.0066 	 datatime: 0.0013 	 batchtime: 1.0529
# [3/3][1215/1535]	Hnet Loss: 0.0029	Rnet Loss: 0.0035	Overall loss: 0.0056 	 datatime: 0.0014 	 batchtime: 1.0550
# [3/3][1220/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0056	Overall loss: 0.0073 	 datatime: 0.0013 	 batchtime: 1.0527
# [3/3][1225/1535]	Hnet Loss: 0.0030	Rnet Loss: 0.0027	Overall loss: 0.0051 	 datatime: 0.0013 	 batchtime: 1.0537
# [3/3][1230/1535]	Hnet Loss: 0.0025	Rnet Loss: 0.0027	Overall loss: 0.0046 	 datatime: 0.0014 	 batchtime: 1.0553
# [3/3][1235/1535]	Hnet Loss: 0.0033	Rnet Loss: 0.0041	Overall loss: 0.0064 	 datatime: 0.0014 	 batchtime: 1.0542
# [3/3][1240/1535]	Hnet Loss: 0.0032	Rnet Loss: 0.0032	Overall loss: 0.0056 	 datatime: 0.0013 	 batchtime: 1.0532
# [3/3][1245/1535]	Hnet Loss: 0.0041	Rnet Loss: 0.0019	Overall loss: 0.0055 	 datatime: 0.0014 	 batchtime: 1.0548
# [3/3][1250/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0025	Overall loss: 0.0049 	 datatime: 0.0014 	 batchtime: 1.0542
# [3/3][1255/1535]	Hnet Loss: 0.0030	Rnet Loss: 0.0026	Overall loss: 0.0049 	 datatime: 0.0014 	 batchtime: 1.0538
# [3/3][1260/1535]	Hnet Loss: 0.0021	Rnet Loss: 0.0025	Overall loss: 0.0040 	 datatime: 0.0013 	 batchtime: 1.0509
# [3/3][1265/1535]	Hnet Loss: 0.0029	Rnet Loss: 0.0026	Overall loss: 0.0049 	 datatime: 0.0017 	 batchtime: 1.0528
# [3/3][1270/1535]	Hnet Loss: 0.0021	Rnet Loss: 0.0020	Overall loss: 0.0036 	 datatime: 0.0015 	 batchtime: 1.0549
# [3/3][1275/1535]	Hnet Loss: 0.0028	Rnet Loss: 0.0030	Overall loss: 0.0050 	 datatime: 0.0014 	 batchtime: 1.0599
# [3/3][1280/1535]	Hnet Loss: 0.0022	Rnet Loss: 0.0020	Overall loss: 0.0037 	 datatime: 0.0014 	 batchtime: 1.0556
# [3/3][1285/1535]	Hnet Loss: 0.0034	Rnet Loss: 0.0039	Overall loss: 0.0064 	 datatime: 0.0017 	 batchtime: 1.0533
# [3/3][1290/1535]	Hnet Loss: 0.0022	Rnet Loss: 0.0023	Overall loss: 0.0040 	 datatime: 0.0017 	 batchtime: 1.0557
# [3/3][1295/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0032	Overall loss: 0.0055 	 datatime: 0.0014 	 batchtime: 1.0534
# [3/3][1300/1535]	Hnet Loss: 0.0027	Rnet Loss: 0.0037	Overall loss: 0.0054 	 datatime: 0.0013 	 batchtime: 1.0528
# [3/3][1305/1535]	Hnet Loss: 0.0019	Rnet Loss: 0.0057	Overall loss: 0.0061 	 datatime: 0.0015 	 batchtime: 1.0528
# [3/3][1310/1535]	Hnet Loss: 0.0026	Rnet Loss: 0.0028	Overall loss: 0.0047 	 datatime: 0.0013 	 batchtime: 1.0550
# [3/3][1315/1535]	Hnet Loss: 0.0023	Rnet Loss: 0.0022	Overall loss: 0.0039 	 datatime: 0.0015 	 batchtime: 1.0558
# [3/3][1320/1535]	Hnet Loss: 0.0018	Rnet Loss: 0.0021	Overall loss: 0.0034 	 datatime: 0.0016 	 batchtime: 1.0537
# [3/3][1325/1535]	Hnet Loss: 0.0043	Rnet Loss: 0.0039	Overall loss: 0.0072 	 datatime: 0.0014 	 batchtime: 1.0527
# [3/3][1330/1535]	Hnet Loss: 0.0039	Rnet Loss: 0.0022	Overall loss: 0.0055 	 datatime: 0.0014 	 batchtime: 1.0533
# [3/3][1335/1535]	Hnet Loss: 0.0024	Rnet Loss: 0.0043	Overall loss: 0.0057 	 datatime: 0.0013 	 batchtime: 1.0558
# [3/3][1340/1535]	Hnet Loss: 0.0025	Rnet Loss: 0.0028	Overall loss: 0.0046 	 datatime: 0.0014 	 batchtime: 1.0573
# [3/3][1345/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0023	Overall loss: 0.0048 	 datatime: 0.0016 	 batchtime: 1.0596
# [3/3][1350/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0021	Overall loss: 0.0046 	 datatime: 0.0018 	 batchtime: 1.0568
# [3/3][1355/1535]	Hnet Loss: 0.0025	Rnet Loss: 0.0019	Overall loss: 0.0039 	 datatime: 0.0014 	 batchtime: 1.0557
# [3/3][1360/1535]	Hnet Loss: 0.0029	Rnet Loss: 0.0034	Overall loss: 0.0055 	 datatime: 0.0014 	 batchtime: 1.0548
# [3/3][1365/1535]	Hnet Loss: 0.0071	Rnet Loss: 0.0055	Overall loss: 0.0112 	 datatime: 0.0013 	 batchtime: 1.0545
# [3/3][1370/1535]	Hnet Loss: 0.0034	Rnet Loss: 0.0055	Overall loss: 0.0075 	 datatime: 0.0017 	 batchtime: 1.0548
# [3/3][1375/1535]	Hnet Loss: 0.0045	Rnet Loss: 0.0025	Overall loss: 0.0064 	 datatime: 0.0014 	 batchtime: 1.0538
# [3/3][1380/1535]	Hnet Loss: 0.0028	Rnet Loss: 0.0014	Overall loss: 0.0038 	 datatime: 0.0017 	 batchtime: 1.0536
# [3/3][1385/1535]	Hnet Loss: 0.0036	Rnet Loss: 0.0031	Overall loss: 0.0060 	 datatime: 0.0014 	 batchtime: 1.0521
# [3/3][1390/1535]	Hnet Loss: 0.0029	Rnet Loss: 0.0033	Overall loss: 0.0054 	 datatime: 0.0015 	 batchtime: 1.0514
# [3/3][1395/1535]	Hnet Loss: 0.0038	Rnet Loss: 0.0029	Overall loss: 0.0060 	 datatime: 0.0014 	 batchtime: 1.0536
# [3/3][1400/1535]	Hnet Loss: 0.0025	Rnet Loss: 0.0032	Overall loss: 0.0049 	 datatime: 0.0014 	 batchtime: 1.0543
# [3/3][1405/1535]	Hnet Loss: 0.0023	Rnet Loss: 0.0017	Overall loss: 0.0036 	 datatime: 0.0013 	 batchtime: 1.0548
# [3/3][1410/1535]	Hnet Loss: 0.0028	Rnet Loss: 0.0031	Overall loss: 0.0052 	 datatime: 0.0017 	 batchtime: 1.0516
# [3/3][1415/1535]	Hnet Loss: 0.0036	Rnet Loss: 0.0067	Overall loss: 0.0086 	 datatime: 0.0013 	 batchtime: 1.0535
# [3/3][1420/1535]	Hnet Loss: 0.0029	Rnet Loss: 0.0028	Overall loss: 0.0050 	 datatime: 0.0014 	 batchtime: 1.0539
# [3/3][1425/1535]	Hnet Loss: 0.0029	Rnet Loss: 0.0038	Overall loss: 0.0057 	 datatime: 0.0014 	 batchtime: 1.0525
# [3/3][1430/1535]	Hnet Loss: 0.0040	Rnet Loss: 0.0043	Overall loss: 0.0072 	 datatime: 0.0013 	 batchtime: 1.0539
# [3/3][1435/1535]	Hnet Loss: 0.0022	Rnet Loss: 0.0031	Overall loss: 0.0046 	 datatime: 0.0014 	 batchtime: 1.0568
# [3/3][1440/1535]	Hnet Loss: 0.0027	Rnet Loss: 0.0031	Overall loss: 0.0050 	 datatime: 0.0013 	 batchtime: 1.0569
# [3/3][1445/1535]	Hnet Loss: 0.0019	Rnet Loss: 0.0031	Overall loss: 0.0042 	 datatime: 0.0014 	 batchtime: 1.0536
# [3/3][1450/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0035	Overall loss: 0.0057 	 datatime: 0.0014 	 batchtime: 1.0548
# [3/3][1455/1535]	Hnet Loss: 0.0026	Rnet Loss: 0.0037	Overall loss: 0.0054 	 datatime: 0.0016 	 batchtime: 1.0535
# [3/3][1460/1535]	Hnet Loss: 0.0023	Rnet Loss: 0.0033	Overall loss: 0.0048 	 datatime: 0.0013 	 batchtime: 1.0478
# [3/3][1465/1535]	Hnet Loss: 0.0029	Rnet Loss: 0.0042	Overall loss: 0.0061 	 datatime: 0.0015 	 batchtime: 1.0546
# [3/3][1470/1535]	Hnet Loss: 0.0032	Rnet Loss: 0.0018	Overall loss: 0.0046 	 datatime: 0.0013 	 batchtime: 1.0545
# [3/3][1475/1535]	Hnet Loss: 0.0021	Rnet Loss: 0.0029	Overall loss: 0.0043 	 datatime: 0.0013 	 batchtime: 1.0529
# [3/3][1480/1535]	Hnet Loss: 0.0023	Rnet Loss: 0.0024	Overall loss: 0.0041 	 datatime: 0.0013 	 batchtime: 1.0539
# [3/3][1485/1535]	Hnet Loss: 0.0025	Rnet Loss: 0.0021	Overall loss: 0.0041 	 datatime: 0.0015 	 batchtime: 1.0557
# [3/3][1490/1535]	Hnet Loss: 0.0035	Rnet Loss: 0.0025	Overall loss: 0.0054 	 datatime: 0.0015 	 batchtime: 1.0540
# [3/3][1495/1535]	Hnet Loss: 0.0023	Rnet Loss: 0.0022	Overall loss: 0.0039 	 datatime: 0.0014 	 batchtime: 1.0515
# [3/3][1500/1535]	Hnet Loss: 0.0023	Rnet Loss: 0.0036	Overall loss: 0.0049 	 datatime: 0.0015 	 batchtime: 1.0525
# [3/3][1505/1535]	Hnet Loss: 0.0027	Rnet Loss: 0.0032	Overall loss: 0.0051 	 datatime: 0.0017 	 batchtime: 1.0535
# [3/3][1510/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0029	Overall loss: 0.0053 	 datatime: 0.0017 	 batchtime: 1.0519
# [3/3][1515/1535]	Hnet Loss: 0.0031	Rnet Loss: 0.0029	Overall loss: 0.0053 	 datatime: 0.0017 	 batchtime: 1.0538
# [3/3][1520/1535]	Hnet Loss: 0.0022	Rnet Loss: 0.0020	Overall loss: 0.0037 	 datatime: 0.0014 	 batchtime: 1.0547
# [3/3][1525/1535]	Hnet Loss: 0.0028	Rnet Loss: 0.0030	Overall loss: 0.0050 	 datatime: 0.0016 	 batchtime: 1.0562
# [3/3][1530/1535]	Hnet Loss: 0.0023	Rnet Loss: 0.0022	Overall loss: 0.0040 	 datatime: 0.0013 	 batchtime: 1.0539
# ----------------------------  one epoch time is 1673.8032  ----------------------------
# Learning rates: Hnet = 0.00100000      Rnet = 0.00100000
# Average Hnet Loss for the epoch=0.003013	 Average Rnet Loss for the epoch=0.004039	 Total Average loss for the epoch=0.006042

# %%
torch.save(Hnet.state_dict(), '/content/drive/My Drive/results/Hnet-Final.pth')
torch.save(Rnet.state_dict(), '/content/drive/My Drive/results/Rnet-Final.pth')
